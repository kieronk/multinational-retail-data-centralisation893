# %%
import boto3
import pandas as pd
from io import StringIO
from io import BytesIO
import re

# %%
def extract_from_s3(s3_uri):
    
    #extract the bucket name and key from the URI 
    uri = re.match(r's3://([^/]+)/(.+)', s3_uri)
    if not uri:
        raise ValueError(f"Invalid S3 URI: {s3_uri}")
    bucket = uri.group(1)
    key = uri.group(2)
    #print('bucket name is:', bucket, '; key name is', key)
    
    #create a client (like a customer service representative going to talk to the S3 dept for me)
    s3 = boto3.client('s3')
 
    # Using a context manager to handle the BytesIO buffer
    with BytesIO() as buffer:
        # Download the file from S3 into the buffer
        s3.download_fileobj(bucket, key, buffer)
    
        # Move to the beginning of the buffer to read its content
        buffer.seek(0)
        
        # Load the data into a pandas DataFrame
        df = pd.read_csv(buffer)
        
    return df 

df = extract_from_s3('s3://data-handling-public/products.csv')

display(df)
# Out:
#       Unnamed: 0                                 product_name product_price  \
# 0              0  FurReal Dazzlin' Dimples My Playful Dolphin        £39.99
# 1              1          Tiffany's World Day Out At The Park        £12.99
# 2              2          Tiffany's World Pups Picnic Playset         £7.00
# 3              3     Tiffany's World Wildlife Park Adventures        £12.99
# 4              4                      Cosatto Cosy Dolls Pram        £30.00
# ...          ...                                          ...           ...
# 1848        1848    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1849        1849    Goodmans Qi Wireless Charging Phone Stand        £15.00
# 1850        1850                     RAC 12V Wet & Dry Vacuum        £18.00
# 1851        1851    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1852        1852               Beldray Telescopic Ladder 2.9m        £69.00
#
#       weight        category            EAN  date_added  \
# 0      1.6kg  toys-and-games  7425710935115  2005-12-02
# 1     0.48kg  toys-and-games   487128731892  2006-01-09
# 2       590g  toys-and-games  1945816904649  1997-03-29
# 3       540g  toys-and-games  1569790890899  2013-03-20
# 4     1.91kg  toys-and-games  7142740213920  2007-12-23
# ...      ...             ...            ...         ...
# 1848    125g             diy  8185827751600  2020-08-28
# 1849    134g             diy  9769724533935  2012-05-20
# 1850    820g             diy  3113855860327  1993-11-28
# 1851    125g             diy  9195087467400  2016-09-20
# 1852   9.4kg             diy  8518402353072  2006-10-07
#
#                                       uuid          removed product_code
# 0     83dc0a69-f96f-4c34-bcb7-928acae19a94  Still_avaliable  R7-3126933h
# 1     712254d7-aea7-4310-aff8-8bcdd0aec7ff  Still_avaliable  C2-7287916l
# 2     b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3     d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 4     7945b657-cb02-4cc5-96cf-f65ed0a8f235  Still_avaliable  B6-2596063a
# ...                                    ...              ...          ...
# 1848  3ff21cb1-8e90-499d-b5a0-6839fb83e70f  Still_avaliable  x4-2227164k
# 1849  a7910f74-c2b6-4144-98b7-30ca68f34d2d  Still_avaliable  i3-8338545Z
# 1850  66d3efa0-f480-4da9-893b-e8aaff53e27b  Still_avaliable  n4-1642658b
# 1851  efb472f1-8f00-448e-a874-9fa9812eeab5  Still_avaliable  A3-7619070S
# 1852  cfe701da-6493-4a7f-83cf-9aab1650f689  Still_avaliable  i6-2851854w
#
# [1853 rows x 10 columns]

# %%
df['weight'].unique()
# Out:
# array(['1.6kg', '0.48kg', '590g', '540g', '1.91kg', '0.91kg', '0.46kg',
#        '0.38kg', '8.981kg', '1.478kg', '1.2g', '0.66kg', '1.8kg', '1.9kg',
#        '1.725kg', '0.54kg', '0.322kg', '0.71kg', '0.88kg', '0.67kg',
#        '11.076kg', '4kg', '0.385kg', '1.38kg', '2.57kg', '1.35kg',
#        '0.695kg', '1.15kg', '0.98kg', '1.447kg', '1.3625kg', '2.25kg',
#        '0.79kg', '0.8kg', '1.08kg', '2.476kg', '0.137kg', '11.5kg',
#        '0.44kg', '2.75kg', '0.911kg', '0.33kg', '1kg', '0.5kg', '0.45kg',
#        '0.7kg', '0.41kg', '1.3kg', '2kg', '0.34kg', '0.37kg', '0.76kg',
#        '1.18kg', '0.685kg', '1.59kg', '1.4kg', '1.66kg', '13.5kg',
#        '0.745kg', '1.44kg', '0.74kg', '0.660kg', '0.419kg', '0.418kg',
#        '0.470kg', '0.353kg', '0.350kg', '0.96kg', '1.20kg', '1.21kg',
#        '1.02kg', '0.365kg', '0.677kg', '0.55kg', '0.43kg', '0.11kg',
#        '1.23kg', '1.03kg', '0.87kg', '0.39kg', '0.35kg', '0.42kg',
#        '0.27kg', '726g', '0.61kg', '0.864kg', '0.667kg', '0.63kg',
#        '0.72kg', '0.58kg', '0.627kg', '0.3kg', '0.32kg', '0.01kg',
#        '0.650kg', '0.68kg', '0.36kg', '1.395kg', '0.9kg', '0.468kg',
#        '0.687kg', '0.955kg', '0.700kg', '0.900kg', '0.06kg', '0.967kg',
#        '0.03kg', '1.041kg', '0.6kg', '0.65kg', '0.59kg', '0.639kg',
#        '0.649kg', '0.354kg', '1.25kg', '0.16kg', '0.258kg', '0.313kg',
#        '0.08kg', '420g', '1.68kg', '0.718kg', '0.92kg', '0.072kg',
#        '1.7kg', '3kg', '1.2kg', '1.505kg', '1.49kg', '0.492kg', '3.3kg',
#        '3.17kg', '2.565kg', '0.443kg', '1.75kg', '0.21kg', '0.86kg',
#        '0.882kg', '0.4kg', '0.77kg', '2.2kg', '1.27kg', '0.809kg',
#        '0.378kg', '3.1kg', '1.84kg', '0.47kg', nan, '1.16kg', '1.1kg',
#        '0.087kg', '0.504kg', '480g', '12 x 100g', '8 x 150g', '6 x 412g',
#        '6 x 400g', '15kg', '160g', '180g', '112g', '120g', '96g', '125g',
#        '110g', '128g', '115g', '170g', '200g', '80g', '130g', '140g',
#        '53g', '500g', '100g', '700g', '750g', '800g', '8 x 85g',
#        '40 x 100g', '12 x 85g', '50g', '300g', '512g', '5.6kg', '6.4kg',
#        '10kg', '14.8kg', '2.9kg', '2.4kg', '6kg', '18.7kg', '11kg',
#        '7.5kg', '4.1kg', '13.7kg', '3.03kg', '3.8kg', '1.071kg', '13kg',
#        '1.5kg', '2.8kg', '6.2kg', '296g', '1.65kg', '1.06kg', '2290g',
#        '1950g', '1675g', '1550g', '1650g', '1450g', '1300g', '1100g',
#        '2200g', '1850g', '1800g', '1500g', '250g', '0.2kg', '1.55kg',
#        '1.40kg', '2100g', '1750g', '0.29kg', '450g', '10.5g', '280g',
#        '230g', '150g', '416g', '163g', '360g', '390g', '1470g', '520g',
#        '270g', '60g', '380g', '350g', '282g', '155g', '2.06kg', '3.2kg',
#        '2.5kg', '10.5kg', '4.3kg', '9kg', '31kg', '12.8kg', '32.1kg',
#        '16.7kg', '23.9kg', '20kg', '11.85kg', '18.5kg', '33kg', '8.2kg',
#        '970g', '2.280kg', '1.280kg', '1.200kg', '1.440kg', '550g', '30g',
#        '1230g', '52g', '45g', '650g', '340g', '265g', '1.09kg', '14g',
#        '998g', '335g', '28kg', '6.25kg', '9.3kg', '28.8kg', '35.5kg',
#        '537g', '375g', '260g', '600g', '61g', '165g', '475g', '26g',
#        '615g', '582g', '430g', '440g', '0.423kg', '0.126kg', '0.22kg',
#        '190g', '370g', '470g', '368g', '410g', '4.6kg', '3.4kg', '2.05kg',
#        '2.1kg', '1.76kg', '2.85kg', '2.36kg', '1.37kg', '1.72kg',
#        '1.73kg', '1.63kg', '0.75kg', '4.53kg', '3.45kg', '2.03kg',
#        '9GO9NZ5JTL', '4.5kg', '12.1kg', '9.4kg', '6.1kg', '4.2kg', '12kg',
#        '21kg', '7.8kg', '5.7kg', '5kg', '1760g', '3.75kg', '4.85kg',
#        '5.5kg', '11.6kg', '10.7kg', '22.5kg', '19.8kg', '8.5kg', '15.5kg',
#        '2.7kg', '27kg', '9.8kg', '12.5kg', '7.3kg', '8.4kg', '5.4kg',
#        '15.8kg', '3.9kg', '6.3kg', '7kg', '6.9kg', '11.2kg', '12.3kg',
#        '11.3kg', '15.6kg', '2.40kg', '2.70kg', '1.32kg', '1.80kg', '2.4g',
#        '1.38g', '3.65kg', '1020g', '1220g', '185g', '887g', '570g',
#        '365g', '0.24kg', '0.51kg', '0.25kg', '0.26kg', '0.81kg', '220g',
#        '310g', '490g', '0.202kg', '630g', 'Z8ZTDGUZVU', '330g', '850g',
#        '936g', '363g', '240g', '856g', '169g', '3.429kg', '2.770kg',
#        '1.870kg', '2.150kg', '1.250kg', '1510g', '1250g', '1700g',
#        '2050g', '1780g', '795g', '320g', '0.28kg', '226g', 'MX180RYSHX',
#        '422g', '184g', '580g', '245g', '7.4kg', '1320g', '1090g',
#        '1.56kg', '1160kg', '1060g', '1580g', '1365g', '2.14kg', '1.782kg',
#        '1.081kg', '0.964kg', '2.66kg', '3.028g', '0.944g', '1.5g',
#        '1.507g', '5.25kg', '3.82kg', '1.95kg', '1.05kg', '1.74kg',
#        '0.89kg', '2.29kg', '810g', '3.85kg', '70g', '100ml', '3 x 2g',
#        '4g', '60ml', '8g', '3 x 90g', '87g', '46g', '95g', '43g', '324g',
#        '152g', '141g', '94g', '351g', '92g', '132g', '105g', '16 x 10g',
#        '425g', '3 x 132g', '5 x 145g', '4 x 400g', '206g', '465g', '395g',
#        '300ml', '800ml', '225g', '167g', '131g', '2 x 200g', '391g',
#        '400g', '275g', '195g', '285g', '248g', '18g', '90g', '216g',
#        '201g', '77g .', '99g', '114g', '0.115kg', '0.196kg', '290g', '3g',
#        '16oz', '274g', '289g', '1.28kg', '820g', '134g'], dtype=object)

# %%
import re
import pandas as pd



def convert_weights_to_kg(): #should contain self
    # Define the regex pattern to match numbers and letters
    pattern = re.compile(r'([0-9.]+)([a-zA-Z]+)')

    # Conversion factors to kg
    conversion_factors = {
        'kg': 1,
        'g': 0.001,
        'oz': 0.0283495231,
        'ml': 0.001  # Assuming ml is equivalent to grams for water-based products
    }

    def convert_to_kg(weight):
        if pd.isna(weight):
            return None  # Handle NaN values
        match = pattern.match(str(weight))
        if match:
            number = float(match.group(1))  # Extract the numeric part
            unit = match.group(2).lower()  # Extract the unit part
            return number * conversion_factors.get(unit, 0)  # Convert to kg
        return None  # Handle cases where regex does not match

    # Apply the conversion to the 'weights' column
    df['weight_in_kg'] = df['weight'].apply(convert_to_kg) # self.df['weight_in_kg'] = self.df['weights'].apply(convert_to_kg)


convert_weights_to_kg()

# Display the updated dataframe
display(df)
# Out:
#       Unnamed: 0                                 product_name product_price  \
# 0              0  FurReal Dazzlin' Dimples My Playful Dolphin        £39.99
# 1              1          Tiffany's World Day Out At The Park        £12.99
# 2              2          Tiffany's World Pups Picnic Playset         £7.00
# 3              3     Tiffany's World Wildlife Park Adventures        £12.99
# 4              4                      Cosatto Cosy Dolls Pram        £30.00
# ...          ...                                          ...           ...
# 1848        1848    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1849        1849    Goodmans Qi Wireless Charging Phone Stand        £15.00
# 1850        1850                     RAC 12V Wet & Dry Vacuum        £18.00
# 1851        1851    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1852        1852               Beldray Telescopic Ladder 2.9m        £69.00
#
#       weight        category            EAN  date_added  \
# 0      1.6kg  toys-and-games  7425710935115  2005-12-02
# 1     0.48kg  toys-and-games   487128731892  2006-01-09
# 2       590g  toys-and-games  1945816904649  1997-03-29
# 3       540g  toys-and-games  1569790890899  2013-03-20
# 4     1.91kg  toys-and-games  7142740213920  2007-12-23
# ...      ...             ...            ...         ...
# 1848    125g             diy  8185827751600  2020-08-28
# 1849    134g             diy  9769724533935  2012-05-20
# 1850    820g             diy  3113855860327  1993-11-28
# 1851    125g             diy  9195087467400  2016-09-20
# 1852   9.4kg             diy  8518402353072  2006-10-07
#
#                                       uuid          removed product_code  \
# 0     83dc0a69-f96f-4c34-bcb7-928acae19a94  Still_avaliable  R7-3126933h
# 1     712254d7-aea7-4310-aff8-8bcdd0aec7ff  Still_avaliable  C2-7287916l
# 2     b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3     d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 4     7945b657-cb02-4cc5-96cf-f65ed0a8f235  Still_avaliable  B6-2596063a
# ...                                    ...              ...          ...
# 1848  3ff21cb1-8e90-499d-b5a0-6839fb83e70f  Still_avaliable  x4-2227164k
# 1849  a7910f74-c2b6-4144-98b7-30ca68f34d2d  Still_avaliable  i3-8338545Z
# 1850  66d3efa0-f480-4da9-893b-e8aaff53e27b  Still_avaliable  n4-1642658b
# 1851  efb472f1-8f00-448e-a874-9fa9812eeab5  Still_avaliable  A3-7619070S
# 1852  cfe701da-6493-4a7f-83cf-9aab1650f689  Still_avaliable  i6-2851854w
#
#       weight_in_kg
# 0            1.600
# 1            0.480
# 2            0.590
# 3            0.540
# 4            1.910
# ...            ...
# 1848         0.125
# 1849         0.134
# 1850         0.820
# 1851         0.125
# 1852         9.400
#
# [1853 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1853 entries, 0 to 1852
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1853 non-null   int64
#  1   product_name   1849 non-null   object
#  2   product_price  1849 non-null   object
#  3   weight         1849 non-null   object
#  4   category       1849 non-null   object
#  5   EAN            1849 non-null   object
#  6   date_added     1849 non-null   object
#  7   uuid           1849 non-null   object
#  8   removed        1849 non-null   object
#  9   product_code   1849 non-null   object
#  10  weight_in_kg   1819 non-null   float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 159.4+ KB

# %%
nan_count = df['weight_in_kg'].isna().sum()
print("Number of NaN values in 'weight_in_kg':", nan_count)

# Show the rows with NaN values in 'weight_in_kg'
nan_rows = df[df['weight_in_kg'].isna()]
print("Rows with NaN values in 'weight_in_kg':")
display(nan_rows)
# Out:
# Number of NaN values in 'weight_in_kg': 34
# Rows with NaN values in 'weight_in_kg':
#       Unnamed: 0                                       product_name  \
# 266          266                                                NaN
# 298          298  Pedigree Vital Protection Dog Food in Jelly 12...
# 299          299            Cesar Country Kitchen Dog Food 8 x 150g
# 300          300              Pedigree Puppy Dog Food in Jelly 12pk
# 301          301                    Pedigree Dog Food in Gravy 12pk
# 302          302                    Pedigree Dog Food in Jelly 12pk
# 303          303                          Chappie Dog Food 6 x 412g
# 304          304  Butcher's Puppy Meaty Chunks in Jelly Tins 6 x...
# 305          305  Pedigree Vital Protection Dog Food in Jelly 12...
# 381          381  Sheba Classics Ocean Selection in Terrine 8 x 85g
# 382          382     Classic Jumbo Pack Cat Food in Jelly 40 x 100g
# 383          383  Sheba Classics Ocean Selection in Terrine 12 x...
# 384          384  Sheba Classics Ocean Selection in Terrine 8 x 85g
# 385          385     Classic Jumbo Pack Cat Food in Jelly 40 x 100g
# 386          386  Sheba Classics Ocean Selection in Terrine 12 x...
# 788          788                                                NaN
# 794          794                                                NaN
# 1133        1133                                         9SX4G65YUX
# 1400        1400                                         LB3D71C025
# 1562        1562                  Just Balmy 2D Wall's Lip Balm Set
# 1563        1563    Just Balmy 2D Barratt Sweet Treats Lip Balm Set
# 1571        1571     Palmolive Natural Soap - Moisture Care 3 x 90g
# 1660        1660                                                NaN
# 1668        1668          Nescafe Dolce Gusto - Latte Machiato 16pk
# 1669        1669              Nescafe Dolce Gusto - Flat White 16pk
# 1676        1676          Nescafe Dolce Gusto - Latte Machiato 16pk
# 1677        1677              Nescafe Dolce Gusto - Flat White 16pk
# 1689        1689            John West Pink Salmon in Brine 3 x 132g
# 1690        1690            Ocean Fresh Tuna Chunks in Oil 5 x 145g
# 1692        1692                         Heinz Tomato Soup 4 x 400g
# 1700        1700            John West Pink Salmon in Brine 3 x 132g
# 1701        1701            Ocean Fresh Tuna Chunks in Oil 5 x 145g
# 1727        1727              Mrs Tilly's Festive Brandy Fudge 400g
# 1752        1752              Mrs Tilly's Festive Brandy Fudge 400g
#
#      product_price      weight           category            EAN  date_added  \
# 266            NaN         NaN                NaN            NaN         NaN
# 298          £4.49   12 x 100g               pets  2439834307647  1995-06-25
# 299          £5.49    8 x 150g               pets  5158002633117  1994-03-22
# 300          £4.49   12 x 100g               pets  5242405808651  2014-05-20
# 301          £4.49   12 x 100g               pets  6160542808008  2020-12-20
# 302          £4.49   12 x 100g               pets  3928398867180  2006-03-27
# 303          £5.99    6 x 412g               pets  8155594260063  1993-06-30
# 304          £4.35    6 x 400g               pets  9386802556862  2019-06-16
# 305          £4.49   12 x 100g               pets  6045981116269  1996-10-12
# 381          £3.49     8 x 85g               pets  5864355297349  2014-01-01
# 382         £10.99   40 x 100g               pets  3610175997493  2003-09-03
# 383          £4.29    12 x 85g               pets  7913138139807  2006-12-10
# 384          £3.49     8 x 85g               pets  8297142436817  2015-04-29
# 385         £10.99   40 x 100g               pets  4130594949815  2011-12-08
# 386          £4.29    12 x 85g               pets  7407445491692  1993-04-22
# 788            NaN         NaN                NaN            NaN         NaN
# 794            NaN         NaN                NaN            NaN         NaN
# 1133    N9D2BZQX63  Z8ZTDGUZVU         C3NCA2CL35     E8EOGWOY8S  09KREHTMWL
# 1400    ODPMASE7V7  MX180RYSHX         WVPMHZP59U     BHPF2JTNKQ  PEPWA0NCVH
# 1562         £4.00      3 x 2g  health-and-beauty  1151910730323  2006-07-30
# 1563         £4.00      3 x 2g  health-and-beauty  9828103898017  1997-03-11
# 1571         £1.00     3 x 90g  health-and-beauty  1692944856882  1997-02-19
# 1660           NaN         NaN                NaN            NaN         NaN
# 1668         £3.69    16 x 10g     food-and-drink  8586844844403  2014-06-05
# 1669         £3.69    16 x 10g     food-and-drink  5015230815305  1992-12-29
# 1676         £3.69    16 x 10g     food-and-drink  8057338051145  2005-08-23
# 1677         £3.69    16 x 10g     food-and-drink  8490641014047  1997-11-09
# 1689         £3.99    3 x 132g     food-and-drink  9395762803091  2022-08-16
# 1690         £3.39    5 x 145g     food-and-drink  3487686391726  1995-02-06
# 1692         £3.39    4 x 400g     food-and-drink  1685057010180  2020-10-10
# 1700         £3.99    3 x 132g     food-and-drink  4758183010205  2006-07-19
# 1701         £3.39    5 x 145g     food-and-drink  9444749850532  2001-05-04
# 1727         £3.99    2 x 200g     food-and-drink  2548181647709  2002-03-02
# 1752         £3.99    2 x 200g     food-and-drink  4880675517869  2022-08-18
#
#                                       uuid          removed product_code  \
# 266                                    NaN              NaN          NaN
# 298   5ec5a431-7330-4d9e-bf3c-702fc85f6efe  Still_avaliable  d4-9698287C
# 299   c379d810-61bf-4ed2-994c-0d3308d5be7b  Still_avaliable  M4-1688574Q
# 300   40963728-bdae-48f1-beec-7c6dd0225921  Still_avaliable  J4-5517838n
# 301   3109d9e8-56b5-4233-a682-0bcdb38182b0  Still_avaliable  v6-1209149g
# 302   28625483-3723-4eaa-9f14-a1a16affbed8  Still_avaliable  C5-0179057G
# 303   6b86f83c-fccf-42eb-b1d5-3971915c18a5  Still_avaliable   Z4-535642u
# 304   a21e8202-de56-40bf-aee9-1b65989b1030  Still_avaliable  x0-3876046p
# 305   39ce65ab-d873-4953-a363-af9a705ca1ef  Still_avaliable  O3-6314460b
# 381   96f4d10f-1cb0-4898-b170-8dcd54c78f05  Still_avaliable  I3-7208040s
# 382   003e2c32-2d88-4ace-9d3c-97863fb62959  Still_avaliable  Y9-9993954b
# 383   e35ab52e-f5db-4e96-b8c0-a9393a5e33a8  Still_avaliable  s3-7992277H
# 384   9df3a039-6cbd-4160-aa45-5f482b236c69  Still_avaliable   m4-507493i
# 385   99cf7bf2-a611-4273-8aac-f426db6c863c  Still_avaliable  H5-5776855X
# 386   e4b978ae-fe4d-4118-a9f8-f8cbd8ff1c71  Still_avaliable  i3-7714502N
# 788                                    NaN              NaN          NaN
# 794                                    NaN              NaN          NaN
# 1133                            CP8XYQVGGU       BPSADIOQOK  BSDTR67VD90
# 1400                            VIBLHHVPMN       H5N71TV8AY   OPSD21HN67
# 1562  6330007c-a70b-41b3-a048-fb38c258d169  Still_avaliable  R9-8669060I
# 1563  68e38307-42c5-4e3f-a27f-f32d05f9a637  Still_avaliable  Z7-8693140R
# 1571  d109ec4d-6f3e-4520-b78a-b34a32fd8f1e  Still_avaliable  c8-1525632E
# 1660                                   NaN              NaN          NaN
# 1668  e3523dd6-8c02-46c4-848f-d7415776acb2  Still_avaliable  P4-7471291z
# 1669  ba73ad16-8998-4799-859d-88691a9c2d54  Still_avaliable  u3-6199715i
# 1676  07aa6951-d029-46ed-8a63-12e3ba9db4b7          Removed  C4-9106468S
# 1677  554505a2-a18d-4d39-bebf-d81ccbff148f  Still_avaliable  C2-4933266o
# 1689  3d8e0941-109f-4c3e-bc16-3de9d200c132  Still_avaliable  W4-1094978l
# 1690  883ff3f7-f6f4-427a-8c10-fe37e0bbf1ed  Still_avaliable  z3-5944487U
# 1692  d4d54e79-cd6d-4f4b-9bee-4058403299de          Removed  G8-4206489Y
# 1700  6f5b78f6-02cd-4ef1-ba53-678109bf9294  Still_avaliable   L5-106382J
# 1701  d64a8810-431f-422d-a0b7-87265bfa702e  Still_avaliable  O2-1543849C
# 1727  9d1dae52-2e77-4299-ac68-68e8e6c8b3e0  Still_avaliable  K8-1086936D
# 1752  d88eedf9-3394-4382-a3d1-85767e5e4ff0  Still_avaliable  M5-8164943v
#
#       weight_in_kg
# 266            NaN
# 298            NaN
# 299            NaN
# 300            NaN
# 301            NaN
# 302            NaN
# 303            NaN
# 304            NaN
# 305            NaN
# 381            NaN
# 382            NaN
# 383            NaN
# 384            NaN
# 385            NaN
# 386            NaN
# 788            NaN
# 794            NaN
# 1133           NaN
# 1400           NaN
# 1562           NaN
# 1563           NaN
# 1571           NaN
# 1660           NaN
# 1668           NaN
# 1669           NaN
# 1676           NaN
# 1677           NaN
# 1689           NaN
# 1690           NaN
# 1692           NaN
# 1700           NaN
# 1701           NaN
# 1727           NaN
# 1752           NaN

# %%
df['removed'].unique()
# Out:
# array(['Still_avaliable', 'Removed', nan, 'T3QRRH7SRP', 'BPSADIOQOK',
#        'H5N71TV8AY'], dtype=object)

# %%
#cleaning df 

def clean_products_data(df): 
    # Drop rows with any NaN values
    df = df.dropna()

    # Drop duplicate rows
    df = df.drop_duplicates()

    # Define the regex pattern to match valid product types
    pattern = re.compile(r'^[a-zA-Z-]+$')

    # Function to check if a value matches the expected product type format
    def is_valid_product_type(column_name):
        if pd.isna(column_name):
            return False
        return bool(pattern.match(str(column_name)))

    #check function is working 
    print('this is removed before applying function', df['removed'].unique()) 
    # Create a boolean mask for valid product types
    valid_product_type_mask = df['category'].apply(is_valid_product_type)

    # Drop rows with non-nonsensical product types
    df = df[valid_product_type_mask].reset_index(drop=True)

    print('this is removed after applying function', df['removed'].unique())

    return df

# Clean the DataFrame
df = clean_products_data(df)
display(df)
# Out:
# this is removed before applying function ['Still_avaliable' 'Removed' 'T3QRRH7SRP']
# this is removed after applying function ['Still_avaliable' 'Removed']
#       Unnamed: 0                                 product_name product_price  \
# 0              0  FurReal Dazzlin' Dimples My Playful Dolphin        £39.99
# 1              1          Tiffany's World Day Out At The Park        £12.99
# 2              2          Tiffany's World Pups Picnic Playset         £7.00
# 3              3     Tiffany's World Wildlife Park Adventures        £12.99
# 4              4                      Cosatto Cosy Dolls Pram        £30.00
# ...          ...                                          ...           ...
# 1813        1848    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1814        1849    Goodmans Qi Wireless Charging Phone Stand        £15.00
# 1815        1850                     RAC 12V Wet & Dry Vacuum        £18.00
# 1816        1851    Goodmans Qi Autosense In Car Phone Holder        £15.00
# 1817        1852               Beldray Telescopic Ladder 2.9m        £69.00
#
#       weight        category            EAN  date_added  \
# 0      1.6kg  toys-and-games  7425710935115  2005-12-02
# 1     0.48kg  toys-and-games   487128731892  2006-01-09
# 2       590g  toys-and-games  1945816904649  1997-03-29
# 3       540g  toys-and-games  1569790890899  2013-03-20
# 4     1.91kg  toys-and-games  7142740213920  2007-12-23
# ...      ...             ...            ...         ...
# 1813    125g             diy  8185827751600  2020-08-28
# 1814    134g             diy  9769724533935  2012-05-20
# 1815    820g             diy  3113855860327  1993-11-28
# 1816    125g             diy  9195087467400  2016-09-20
# 1817   9.4kg             diy  8518402353072  2006-10-07
#
#                                       uuid          removed product_code  \
# 0     83dc0a69-f96f-4c34-bcb7-928acae19a94  Still_avaliable  R7-3126933h
# 1     712254d7-aea7-4310-aff8-8bcdd0aec7ff  Still_avaliable  C2-7287916l
# 2     b089ef6f-b628-4e37-811d-fffe0102ba64  Still_avaliable  S7-1175877v
# 3     d55de422-8b98-47d6-9991-e4bc4c5c0cb0          Removed  D8-8421505n
# 4     7945b657-cb02-4cc5-96cf-f65ed0a8f235  Still_avaliable  B6-2596063a
# ...                                    ...              ...          ...
# 1813  3ff21cb1-8e90-499d-b5a0-6839fb83e70f  Still_avaliable  x4-2227164k
# 1814  a7910f74-c2b6-4144-98b7-30ca68f34d2d  Still_avaliable  i3-8338545Z
# 1815  66d3efa0-f480-4da9-893b-e8aaff53e27b  Still_avaliable  n4-1642658b
# 1816  efb472f1-8f00-448e-a874-9fa9812eeab5  Still_avaliable  A3-7619070S
# 1817  cfe701da-6493-4a7f-83cf-9aab1650f689  Still_avaliable  i6-2851854w
#
#       weight_in_kg
# 0            1.600
# 1            0.480
# 2            0.590
# 3            0.540
# 4            1.910
# ...            ...
# 1813         0.125
# 1814         0.134
# 1815         0.820
# 1816         0.125
# 1817         9.400
#
# [1818 rows x 11 columns]

# %%
df['removed'].unique()
# Out:
# array(['Still_avaliable', 'Removed'], dtype=object)

# %%
df['category'].unique()
# Out:
# array(['toys-and-games', 'sports-and-leisure', 'pets', 'homeware',
#        'health-and-beauty', 'food-and-drink', 'diy'], dtype=object)
